# %%
# Libraries for interfacing with WFDB data
import wfdb
from wfdb import processing



#Classical libraries 
import matplotlib.pyplot as plt
import matplotlib as mpl

import numpy as np
import pandas as pd

from scipy.integrate import quad
from scipy.optimize import curve_fit
from numpy import trapz
from scipy.stats import norm



# importing detrending library
import obspy
from obspy.signal import detrend

# %% [markdown]
# ## This function its used to store the ECG data inside the original files into a Pandas Dataframe

# %%
def import_ecg(path, files):
    
    '''
    Return ECG and RR_intervals dataframe.
    
    Inputs:
        path: path to the data's files
        files: files name without extentions
    
    outputs:
    return:
        ECG_sig: DataFrame with EGC signal for each file in each columns
        RR_intervals: DataFrame where in each columns are stored the interbeats intervals for each files
    '''


    # DataFrames to handle all signals (RAW ECG, RR intervals, Annotations, ...)
    ECG_sig=pd.DataFrame(columns=files)

    RR_intervals = pd.DataFrame(columns=files)



    # Read ECG data from files and store them in Pandas DataFrame
    # Save fields too, for further optional analysis
    signals_dfs=[]
    rr_dfs=[]

    for file in files:
        """ sig, fields =  wfdb.rdsamp(path + file, channels=[1]) # channel 1 maps to ECG data
        signals_dfs.append(pd.DataFrame({file: sig.T[0]}))

        xqrs = processing.XQRS(sig=sig[:,0], fs=fields['fs'])
        xqrs.detect()
        rr=processing.calc_rr(xqrs.qrs_inds, fs=fields['fs']) """

        #checking for problematic files
        #if np.sum(rr)==0:
        rr = processing.ann2rr(path+file, extension='ecg')
        rr_dfs.append(pd.DataFrame({file: rr}))

    """ ECG_sig=pd.concat(signals_dfs, ignore_index=True, axis=1)
    ECG_sig.columns=files """

    RR_intervals=pd.concat(rr_dfs, ignore_index=True, axis=1)
    RR_intervals.columns=files
    
    """ return ECG_sig, RR_intervals """
    return RR_intervals

# %% [markdown]
# ## This function find problematic files and uses the annotation files to correct them
# #### fixing this after loading the data inside the dataframe is a computationally faster way since we all already have the data stored inside the .hdf file and we need only to replace the corrupted column

# %%
def clean_df(RR_intervals, path_to_files):
    
    RR = RR_intervals.copy()
    files = list(RR.columns)
    
    #Extracting the problematc files name
    problematic_files = list(RR.columns[RR[files].sum() == 0])
    
    #Removing from the file list the problematic ones
    files = list(RR.columns[RR[files].sum() != 0])
    
    #Removing the columns which bare no value
    RR = RR.drop(problematic_files, axis=1)
    
    #Adding the new columns to the dataframe and the files name to the list
    for file in problematic_files:
        rr = processing.ann2rr(path_to_files+file, extension='ecg')
        RR = pd.concat([RR, pd.Series(rr, name=file)], axis=1)

    new_files = files + problematic_files
    
    return RR, new_files

# %% [markdown]
# ## Function to compute the detrended data and then the increments from the comulative function

# %%
def increments(B_df, s_list, polydegree=3):
    '''
    Inputs:
        B: Dataframe with the columns to be detrended
        s_list: List of value of s to be used to detrend B
        polydegree: Polynomial's degree used to detred the data
    
    Output:
        return : List of array containing the detrended data increments for each column of B
    
    '''
    fnames = list(B_df.columns) #columns name list
    list_DB=[]
    
    for s in s_list:
        
        Delta_B_s=[] #empy list to store the increamets for a specific s regardless of the file from which the data come from

        
        for B in B_df[fnames].values.T:
            
            B = B[~np.isnan(B)] #removing all nan values from B     
            nmax_seg=int(np.floor(B.size/(2*s))) #maximum number of possible segments with increment s over B
            
            
            if nmax_seg!= 0: #avoid useless computing power
                
                for indx in range(nmax_seg):
                    detrend.polynomial(B[indx*2*s: (indx+1)*2*s], order=polydegree, plot=False) # for each sliding segment, detrend

                # the whole B but now detrended
                #detrended=B[0:2*s*nmax_seg].copy() #only those that are possible to detrend (have at least the 2s space/segment)
                detrended=B[0:2*s*nmax_seg]
                Delta_s_B_file=np.array([detrended[i+s]-detrended[i] for i in range(2*s*nmax_seg) if i+s< len(detrended)])
                Delta_B_s.append(Delta_s_B_file/np.std(Delta_s_B_file)) #since the std of very patient i svery different from each other we need to normalize the increments and join them togheter
        list_DB.append(np.concatenate(Delta_B_s))
    
    return list_DB

# %% [markdown]
# ## Defining gaussian and Castaing's functions to fit the data

# %%
def gaus(x, mu, sigma, A):
    return A/np.sqrt(2*np.pi*sigma**2)*np.exp(-(x - mu)**2 / (2*sigma**2))

# %%
def castaing_integral(x, lambd, sigma_0):
    def little_cast(sigma, lambd, x, sigma_0):
        return 1/(2*np.pi*lambd*sigma**2)*np.exp(-(x**2/sigma**2 + np.log(sigma/sigma_0)**2/lambd**2) / 2)
    result = quad(little_cast, 0, np.inf, args=(lambd, x, sigma_0))
    return result[0]

# scipy_integrate accepts only scalar functions, we can vectorize it this way
Castaing_integral = np.vectorize(castaing_integral)

# %% [markdown]
# ## Setting the path to the data and the file's name in order to access them

# %%
path='physionet.org/files/fantasia/1.0.0/' # relative path to data files
files= np.loadtxt(path+'RECORDS', dtype='str') # name of all files (no extensions as required by wfdb functions)

# %% [markdown]
# ## This cell is meant to run only when first importing the data

# %%
""" #Since we do not use anymore the XQRS algortihm, we do not have i sig file
ECG_sig, RR_intervals_original = import_ecg(path, files)
ECG_sig.to_hdf('ECG_sig.hdf', key='ECG_sig_Fantasia') 
""" 
#decoment the following line if you want to save the RR_intervals_originals
""" RR_intervals_original = import_ecg(path, files)
RR_intervals_original.to_hdf('RR_intervals_original.hdf', key='RR_intervals_original_Fantasia')  """
# Out:
# " RR_intervals_original = import_ecg(path, files)\nRR_intervals_original.to_hdf('RR_intervals_original.hdf', key='RR_intervals_original_Fantasia')  "

# %% [markdown]
# ## Loading the data inside a Dataframe for easier manipulation

# %%
RR_intervals_original=pd.read_hdf('RR_intervals_original.hdf', key='RR_intervals_original_Fantasia')
RR_intervals_original.describe()
# Out:
#             f1o01        f1o02        f1o03        f1o04        f1o05  \
# count  7169.00000  6823.000000  7228.000000  6230.000000  5730.000000
# mean    252.85507   265.413015   250.891118   290.682343   271.959511
# std      12.05276    11.182137    12.759428    29.414647    10.934855
# min     167.00000    75.000000   118.000000    98.000000   186.000000
# 25%     246.00000   260.000000   244.000000   275.000000   264.000000
# 50%     254.00000   266.000000   251.000000   292.000000   271.000000
# 75%     262.00000   271.000000   259.000000   306.000000   280.000000
# max     282.00000   383.000000   336.000000  1820.000000   318.000000
#
#              f1o06        f1o07        f1o08        f1o09        f1o10  ...  \
# count  6231.000000  7150.000000  8488.000000  4925.000000  8241.000000  ...
# mean    292.043813   253.034126   212.388195   367.528934   220.036403  ...
# std       7.367699    17.318108    11.575439    32.130222    14.379416  ...
# min     146.000000   120.000000    65.000000   148.000000   128.000000  ...
# 25%     289.000000   245.000000   206.000000   354.000000   211.000000  ...
# 50%     292.000000   254.000000   213.000000   369.000000   220.000000  ...
# 75%     296.000000   263.000000   220.000000   386.000000   230.000000  ...
# max     362.000000   379.000000   266.000000   447.000000   267.000000  ...
#
#              f2y01        f2y02        f2y03        f2y04        f2y05  \
# count  8106.000000  6574.000000  6807.000000  8603.000000  9248.000000
# mean    218.179373   356.326285   258.330689   205.012786   189.794442
# std      16.352506    36.468262    10.376207    13.163869    15.508532
# min     100.000000   248.000000    76.000000    64.000000    60.000000
# 25%     210.000000   332.000000   253.000000   198.000000   184.000000
# 50%     220.000000   356.000000   259.000000   206.000000   192.000000
# 75%     229.000000   381.000000   265.000000   213.000000   199.000000
# max     300.000000   549.000000   294.000000   277.000000   500.000000
#
#              f2y06        f2y07        f2y08        f2y09        f2y10
# count  6851.000000  6510.000000  7378.000000  8811.000000  7114.000000
# mean    256.205226   269.420737   245.285037   204.540120   252.135367
# std      18.716047    25.762242    28.560924    37.048072    75.400443
# min      56.000000   105.000000    48.000000     1.000000    64.000000
# 25%     244.000000   254.000000   230.000000   192.000000   240.000000
# 50%     255.000000   269.000000   245.000000   205.000000   253.000000
# 75%     269.000000   286.000000   263.000000   220.000000   264.000000
# max     333.000000   362.000000   397.000000   408.000000  6267.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# ## Clensing the dataframe from the Nan columns

# %%
RR_intervals, files = clean_df(RR_intervals_original, path)

# %% [markdown]
# ## We clean the data redefining the ones that exede the interval (mean - f x std, mean+f x std)

# %%
factor=3

for file in files:
    mean = RR_intervals[file].mean()
    std  = RR_intervals[file].std()

    RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# Out:
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean
# /tmp/ipykernel_636/2957418626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_intervals[file][(RR_intervals[file] > mean + factor*std) | ( RR_intervals[file]< mean - factor*std)]=mean

# %% [markdown]
# # Constructing the cumulative functions from the beats intervals

# %%
B=pd.DataFrame(np.cumsum(RR_intervals, axis=0))
B # columns names are correct
# Out:
#            f1o01        f1o02        f1o03        f1o04   f1o05        f1o06  \
# 0      252.85507   265.413015   250.891118   290.682343   245.0   292.043813
# 1      500.85507   506.413015   501.782236   599.682343   499.0   604.043813
# 2      745.85507   740.413015   752.673354   909.682343   748.0   911.043813
# 3      992.85507   980.413015  1003.564471  1220.682343   997.0  1222.043813
# 4     1242.85507  1216.413015  1254.455589  1536.682343  1248.0  1529.043813
# ...          ...          ...          ...          ...     ...          ...
# 9243         NaN          NaN          NaN          NaN     NaN          NaN
# 9244         NaN          NaN          NaN          NaN     NaN          NaN
# 9245         NaN          NaN          NaN          NaN     NaN          NaN
# 9246         NaN          NaN          NaN          NaN     NaN          NaN
# 9247         NaN          NaN          NaN          NaN     NaN          NaN
#
#        f1o07       f1o08        f1o09        f1o10  ...        f2y01   f2y02  \
# 0      219.0  212.388195   367.528934   220.036403  ...   218.179373   283.0
# 1      466.0  397.388195   735.528934   446.036403  ...   464.179373   591.0
# 2      712.0  586.388195  1105.528934   672.036403  ...   697.179373   911.0
# 3      952.0  775.388195  1476.528934   891.036403  ...   923.179373  1213.0
# 4     1209.0  966.388195  1843.528934  1111.036403  ...  1148.179373  1511.0
# ...      ...         ...          ...          ...  ...          ...     ...
# 9243     NaN         NaN          NaN          NaN  ...          NaN     NaN
# 9244     NaN         NaN          NaN          NaN  ...          NaN     NaN
# 9245     NaN         NaN          NaN          NaN  ...          NaN     NaN
# 9246     NaN         NaN          NaN          NaN  ...          NaN     NaN
# 9247     NaN         NaN          NaN          NaN  ...          NaN     NaN
#
#             f2y03       f2y04         f2y05        f2y06        f2y07  \
# 0      258.330689  205.012786  1.897944e+02   256.205226   269.420737
# 1      515.330689  394.012786  3.827944e+02   492.205226   513.420737
# 2      765.330689  577.012786  5.787944e+02   733.205226   732.420737
# 3     1027.330689  763.012786  7.757944e+02   971.205226   949.420737
# 4     1288.330689  950.012786  9.687944e+02  1213.205226  1165.420737
# ...           ...         ...           ...          ...          ...
# 9243          NaN         NaN  1.758200e+06          NaN          NaN
# 9244          NaN         NaN  1.758378e+06          NaN          NaN
# 9245          NaN         NaN  1.758555e+06          NaN          NaN
# 9246          NaN         NaN  1.758729e+06          NaN          NaN
# 9247          NaN         NaN  1.758908e+06          NaN          NaN
#
#             f2y08       f2y09   f2y10
# 0      245.285037  100.000000   248.0
# 1      475.285037  304.540120   486.0
# 2      708.285037  416.540120   730.0
# 3      933.285037  621.080241   893.0
# 4     1172.285037  739.080241  1052.0
# ...           ...         ...     ...
# 9243          NaN         NaN     NaN
# 9244          NaN         NaN     NaN
# 9245          NaN         NaN     NaN
# 9246          NaN         NaN     NaN
# 9247          NaN         NaN     NaN
#
# [9248 rows x 40 columns]

# %% [markdown]
# ## Defining the values for s and computing the increments

# %%
S=[2**i for i in range(3, 12)]
list_Delta_B= increments(B, S, polydegree=3 )

# %%
tab20=mpl.colormaps['tab20']
colors=tab20(range(9))

# %% [markdown]
# ## Plotting the fitted increments using a gaussian fit

# %%
for i, DBs in enumerate(list_Delta_B):
    counts, edges=np.histogram(DBs, bins=int(np.sqrt(DBs.size)), range=(-10, 10))
    bin_cen=(edges[1:]+edges[:-1])/2
        
    popt, pcov = curve_fit(gaus , bin_cen, counts/(S[i]*len(DBs)), p0=[1,1,1])
    
    x = np.linspace(-5, 5, 100)
    plt.plot(x, gaus(x, *popt), color=colors[i])
    
    plt.scatter(bin_cen, counts/(S[i]*len(DBs)), s=1, color=colors[i], label=f's = {S[i]}')


plt.yscale('log')
plt.ylim(1e-10, 1e-2)
plt.ylabel(r'$P_s(\Delta_s B)$')
plt.xlabel(r'$\Delta_s B/\sigma$')
plt.legend(bbox_to_anchor=(1.02, 0.75), loc='upper left', borderaxespad=0)
plt.grid(linestyle='dotted')

# %% [markdown]
# ## Plotting the fitted data using the Castaing equation

# %%
for i,DBs in enumerate(list_Delta_B[:-1]):
    
    counts, edges=np.histogram(DBs, bins=int(np.sqrt(DBs.size)), range=(-10, 10))
    bin_cen=(edges[1:]+edges[:-1])/2
    counts=counts/np.trapz(counts, bin_cen)

    plt.scatter(bin_cen, counts/S[i], s=3, label=f's = {S[i]}', color=colors[i])
    
    popt, pcov = curve_fit(Castaing_integral, bin_cen, counts, p0=[np.sqrt(0.16), 1])
    
    
    
    x=np.linspace(-10, 10, 200)
    #plt.plot(x, Castaing_integral(x, *popt)/S[i], label='Cast {:.3f}'.format(*popt), label=f's = {S[i]}', color=colors[i])
    plt.plot(x, Castaing_integral(x, *popt)/S[i],  color=colors[i], label=r'$\lambda$ = {:.3f}'.format(*popt))
    print(S[i],'(lamda, sigma0)', *popt)


plt.legend(loc=(1,0))
#plt.xlim(-2,2)
plt.yscale('log')
#plt.ylim(10e-6, 10e1)
plt.grid(linestyle='dotted')
#plt.xlim(-1,1)
plt.ylim(1e-7, 1e-1)
plt.ylabel(r'$P_s(\Delta_s B)$')
plt.xlabel(r'$\Delta_s B/\sigma$')
plt.legend(bbox_to_anchor=(1.3, 0.96), borderaxespad=0)
plt.grid(linestyle='dotted')
plt.show()
# Out:
# 8 (lamda, sigma0) 0.41126699376637094 0.8567551239341101
# 16 (lamda, sigma0) 0.40554566088173466 0.8817243814552216
# 32 (lamda, sigma0) 0.3729653403788642 0.9022175263040079
# 64 (lamda, sigma0) 0.3085773795741781 0.9279402456553604
# 128 (lamda, sigma0) 0.3107456857687433 0.9291412610523699
# 256 (lamda, sigma0) 0.28972196467706657 0.940134649370933
# 512 (lamda, sigma0) 0.22243316120632567 0.9625565786834722
# 1024 (lamda, sigma0) 0.22041977741247348 0.9874159150398266

# %% [markdown]
# ## Generating the collapse plot from all data

# %%
complete_dataset=np.concatenate(list_Delta_B)

# %%
for i,DBs in enumerate(list_Delta_B):
    counts, edges=np.histogram(DBs, bins=int(np.sqrt(DBs.size)), range=(-10, 10))
    bin_cen=(edges[1:]+edges[:-1])/2
    #print('Area before norm',np.trapz(counts, bin_cen))
    #plt.scatter(bin_cen, counts, s=3)

    #print('SONO UGUALI?',len(d), np.sum(counts))
    counts=counts/np.trapz(counts, bin_cen)

    #print('Area after norm',np.trapz(counts, bin_cen))
    plt.scatter(bin_cen, counts, s=3, label=f's = {S[i]}' , color=colors[i])

    mu, std=norm.fit(counts, fscale=1) # to imporove to properly fit data
    #print(std)
    #p = norm.pdf(x, mu, std)

    #
    #print(S[i],'lambda=', *popt)

    #for i in range(1,20):
    #plt.plot(x, Castaing_integral(x, 0.3), label='Cast '+str(0.3))

x=np.linspace(-10, 10, 200)
counts_all, edges_all=np.histogram(complete_dataset, bins=int(np.sqrt(complete_dataset.size)), range=(-10, 10))

bin_cen_all=(edges_all[1:]+edges_all[:-1])/2
counts_all=counts_all/np.trapz(counts_all, bin_cen_all)

popt, pcov = curve_fit(Castaing_integral, bin_cen_all, counts_all, p0=[np.sqrt(0.16), 1])
plt.plot(x, Castaing_integral(x, *popt), label=r'$\lambda$ = {:.3f}'.format(*popt), color='black')

popt_g, pcov_g = curve_fit(gaus, bin_cen_all, counts_all, p0=[np.sqrt(0.16), 1, 1])
plt.plot(x, gaus(x, *popt_g), label='Gaus {:.3f}'.format(*popt_g), color='black', alpha=0.5)

print(counts_all.shape, Castaing_integral(bin_cen_all, *popt).shape)
#print('Chi all',chisquare(f_obs=counts_all, f_exp=Castaing_integral(bin_cen_all, *popt), ddof=2))
chi_2=np.sum((counts_all[counts_all!=0]-Castaing_integral(bin_cen_all[counts_all!=0], *popt))**2/(counts_all[counts_all!=0]))/(counts_all[counts_all!=0].shape[0]-2)
print('Chi squared', chi_2)

chi_2_g=np.sum((counts_all[counts_all!=0]-gaus(bin_cen_all[counts_all!=0], *popt_g))**2/(counts_all[counts_all!=0]))/(counts_all[counts_all!=0].shape[0]-2)
print('Chi squared g', chi_2_g)


plt.legend(loc=(1,0))
#plt.xlim(-2,2)
plt.yscale('log')
#plt.ylim(10e-6, 10e1)
plt.grid(linestyle='dotted')
#plt.xlim(-1,1)
plt.xlim(-10,10)
plt.ylim(1e-5, 1e0)
plt.ylabel(r'$P_s(\Delta_s B)$')
plt.xlabel(r'$\Delta_s B/\sigma$')
plt.legend(bbox_to_anchor=(1.02, 0.75), loc='upper left', borderaxespad=0)
plt.show()
# Out:
# (1499,) (1499,)
# Chi squared 0.0002598349274549158
# Chi squared g 0.0016419470119206742

# %% [markdown]
# # Mean flactuation function

# %%
 def F(B_df, s_list):
    '''
    Inputs:
        B: Dataframe with the columns to find the mean flactuation function 
        s_list: List of value of s to be used to find the mean flactuation function 
    
    Output:
        return : List of array containing the detrended data increments for each column of B
    
    '''
     #columns name list
    list_DB=[]
    
    for s in s_list:
        if type(B_df)==np.ndarray:
            B=B_df        
        else: 
            B=B_df.values   
        B = B[~np.isnan(B)] #removing all nan values from B     
        nmax_seg=int(np.floor(B.size/(2*s))) #maximum number of possible segments with increment s over B
    
        if nmax_seg!= 0: #avoid useless computing power
            Delta_s_B_file=np.array([abs(B[i+s]-B[i]) for i in range(2*s*nmax_seg) if i+s<len(B)])
        list_DB.append(Delta_s_B_file)
    
    return list_DB

# %%
def F_detrend(B_df, s_list, f_s=250, deg=1):
    '''
    Inputs:
        B: Dataframe with the columns to find the mean flactuation function 
        s_list: List of value of s to be used to find the mean flactuation function 
    
    Output:
        return : List of array containing the detrended data increments for each column of B
    
    '''
     #columns name list
    list_DB=[]
    
    for s in s_list:
        
        B=B_df.values.copy()
            
        B = B[~np.isnan(B)] #removing all nan values from B     
        nmax_seg=int(np.floor(B.size/(2*s))) #maximum number of possible segments with increment s over B
    
        if nmax_seg!= 0: #avoid useless computing power
            detrend.polynomial(B, order=deg, plot=False)
            detrended=B[0:2*s*nmax_seg]
            print(detrend)
            Delta_s_B_file=np.array([abs(detrend[i+s]-detrend[i]) for i in range(2*s*nmax_seg) if i+s<(2*s*nmax_seg)])
        
        list_DB.append(Delta_s_B_file)
    
    return list_DB

# %%
S=np.arange(200, 4000, 20, dtype=int)
a=pd.DataFrame(B.loc[:, 'f1o01'])
print(a, type(a))
# Out:
#            f1o01
# 0      252.85507
# 1      500.85507
# 2      745.85507
# 3      992.85507
# 4     1242.85507
# ...          ...
# 9243         NaN
# 9244         NaN
# 9245         NaN
# 9246         NaN
# 9247         NaN
#
# [9248 rows x 1 columns] <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Detrending

# %%
c = a.copy()
c = c.values/250
c = c[~np.isnan(c)]
print(c)
detrend.polynomial(c, order=1, plot=False)
index=[]
comulative=[]
for i, c_i in enumerate(c):
    index.append(i)
    comulative.append(c_i)

plt.plot(index, comulative)
# Out:
# [1.01142028e+00 2.00342028e+00 2.98342028e+00 ... 7.25461003e+03
#  7.25554603e+03 7.25652203e+03]

# %%
list_F = F(c, S)
#print(np.array(list_F).shape)
#[len(f) for f in list_F]

# %%
df=pd.DataFrame()
for i, f in enumerate(list_F):
    df = pd.concat([df, pd.Series(np.mean(f), name=S[i])], axis=1)
df
# Out:
#          200         220         240         260        280         300   \
# 0  202.784092  222.978672  243.416269  263.677021  284.00456  304.438463
#
#          320         340         360         380   ...         3800  \
# 0  324.491643  344.839856  365.473369  385.437448  ...  3646.680052
#
#           3820         3840         3860         3880         3900  \
# 0  3646.680052  3646.680052  3646.680052  3646.680052  3646.680052
#
#           3920         3940         3960         3980
# 0  3646.680052  3646.680052  3646.680052  3646.680052
#
# [1 rows x 190 columns]

# %%
index=[]
mean=[]
for i, f in enumerate(list_F):
    print(len(f),'\n',  f/(S[i]), '\n')
    index.append(S[i])
    mean.append(np.mean(f)/(S[i]))
# Out:
# 6800
#  [12.3817837  12.3717837  12.3467837  ...  5.05968229  5.01468229
#   4.98968229]
#
# 6949
#  [12.29223824 12.29223824 12.29223824 ...  8.45073632  8.53644119
#   8.57669151]
#
# 6720
#  [12.32595036 12.35095036 12.3842837  ...  7.96169919  7.94503252
#   7.90753252]
#
# 6760
#  [12.48139908 12.51216831 12.51216831 ...  5.25285954  5.21055184
#   5.1720903 ]
#
# 6720
#  [13.15392655 13.24321227 13.31821227 ...  6.67742555  6.63099698
#   6.58813983]
#
# 6600
#  [12.69011703 12.6867837  12.68345036 ...  5.5367837   5.5667837
#   5.6067837 ]
#
# 6849
#  [12.3874087  12.3655337  12.3436587  ...  8.63165693  8.68478193
#   8.70040693]
#
# 6800
#  [12.08501899 12.1085484  12.12031311 ...  5.87790051  5.9543711
#   5.94303266]
#
# 6480
#  [12.10789481 12.13011703 12.1467837  ...  5.43011703  5.39956147
#   5.3467837 ]
#
# 6789
#  [11.9467837  11.94941527 11.94415212 ...  7.33141379  7.37351906
#   7.38667695]
#
# 6400
#  [11.7567837 11.7417837 11.7167837 ...  5.6717837  5.6592837  5.6417837]
#
# 6720
#  [11.67773608 11.69202179 11.71583131 ...  6.80054493  6.85292588
#   6.82708048]
#
# 6729
#  [11.56951097 11.56723824 11.56269279 ...  7.86305514  7.88350969
#   7.8676006 ]
#
# 6440
#  [11.43591413 11.44243587 11.45113152 ...  4.8315663   4.83808804
#   4.8467837 ]
#
# 6689
#  [11.4467837  11.4967837  11.53845036 ...  8.04294919  8.06586586
#   8.06794919]
#
# 6669
#  [11.4367837  11.4247837  11.4067837  ...  8.01510257  8.02510257
#   8.02510257]
#
# 6240
#  [11.28524523 11.30832216 11.32755293 ...  5.38139908  5.39101447
#   5.40255293]
#
# 6480
#  [11.2004874  11.18752444 11.17456147 ...  5.53859799  5.53304243
#   5.51452391]
#
# 6609
#  [10.89321227 10.90035512 10.91285512 ...  7.42742555  7.48278269
#   7.5095684 ]
#
# 6589
#  [10.86402508 10.85540439 10.84161128 ...  7.06429997  7.09361031
#   7.1160241 ]
#
# 6000
#  [10.65845036 10.65511703 10.6517837  ...  3.42845036  3.44345036
#   3.45345036]
#
# 6200
#  [10.34194499 10.3500095  10.35807402 ...  5.50323531  5.49355789
#   5.47904176]
#
# 6400
#  [9.9983462  9.9936587  9.9858462  ... 5.20081451 5.19456451 5.18675201]
#
# 6509
#  [10.26540469 10.29267742 10.31691985 ...  6.64551011  6.68944951
#   6.72581315]
#
# 6489
#  [10.3045629  10.3045629  10.30015114 ...  6.67495934  6.67790051
#   6.67348875]
#
# 6469
#  [10.29719778 10.29719778 10.29005492 ...  6.79558289  6.83415432
#   6.85844003]
#
# 5760
#  [10.16663072 10.16246406 10.15829739 ...  1.6194085   1.6444085
#   1.68051961]
#
# 5920
#  [10.10393215 10.0998781  10.0971754  ...  2.33327018  2.35354045
#   2.38462153]
#
# 6080
#  [10.11427035 10.11690193 10.11427035 ...  4.88888896  4.86652054
#   4.8467837 ]
#
# 6240
#  [9.99843736 9.99330916 9.98305275 ... 5.33855257 5.33086026 5.32573205]
#
# 6369
#  [9.98714602 9.99714602 9.99964602 ... 6.35198299 6.38448299 6.40698299]
#
# 6349
#  [10.0093323  10.01055182 10.00567377 ...  6.5542952   6.56527081
#   6.56039276]
#
# 6329
#  [9.95070019 9.95665258 9.97808115 ... 6.43149731 6.46125922 6.47792588]
#
# 6309
#  [9.92851609 9.92851609 9.92037656 ... 6.36906211 6.39115513 6.40394583]
#
# 6289
#  [9.72552217 9.72665854 9.73006763 ... 6.32082851 6.33560124 6.33787396]
#
# 5400
#  [9.68043909 9.67710576 9.66710576 ... 2.93622757 2.92067202 2.89956091]
#
# 5520
#  [9.58840311 9.58949006 9.58731615 ... 0.53877081 0.52029254 0.50833602]
#
# 5640
#  [9.52262397 9.52262397 9.51411333 ... 1.20241121 1.19283674 1.18538993]
#
# 5760
#  [9.5293773  9.5450023  9.55229397 ... 2.38146063 2.40541897 2.43146063]
#
# 5880
#  [9.56442641 9.58483457 9.59809988 ... 2.9345388  2.93147757 2.93351839]
#
# 6000
#  [9.77907356 9.77707356 9.76407356 ... 4.47436341 4.48436341 4.49736341]
#
# 6120
#  [9.65491101 9.66961689 9.6813816  ... 5.48656773 5.52284224 5.51808237]
#
# 6129
#  [9.8018701  9.78648548 9.77110087 ... 5.97386008 5.98059085 5.97674469]
#
# 6109
#  [9.65743451 9.65366092 9.65083073 ... 5.88372656 5.91108505 5.93372656]
#
# 6089
#  [9.71001505 9.70353357 9.69149653 ... 5.84137577 5.83211651 5.81267206]
#
# 6069
#  [9.59613811 9.60068357 9.59886539 ... 5.84329227 5.86329227 5.87238318]
#
# 6049
#  [9.52114964 9.5220425  9.51936393 ... 5.70496176 5.72460462 5.73621176]
#
# 6029
#  [9.55931866 9.5663362  9.56545901 ... 5.66095864 5.68815162 5.70481829]
#
# 6009
#  [9.52461978 9.5297922  9.5323784  ... 5.42536942 5.4564039  5.47881769]
#
# 5989
#  [9.55804629 9.55719883 9.55296154 ... 5.14861373 5.17488491 5.19098661]
#
# 4800
#  [9.68869191 9.70119191 9.70785858 ... 6.98797475 6.99630809 7.00464142]
#
# 4880
#  [9.72325079 9.72161145 9.71997211 ... 6.67838855 6.68494593 6.69806068]
#
# 4960
#  [9.65669487 9.65266261 9.64701745 ... 5.74814384 5.74733739 5.74249868]
#
# 5040
#  [9.59225184 9.59066454 9.58748993 ... 4.62838308 4.62600213 4.61806562]
#
# 5120
#  [9.5149789  9.5149789  9.51419765 ... 3.5115836  3.49205235 3.47173985]
#
# 5200
#  [9.44700666 9.44239128 9.43700666 ... 2.73068564 2.7045318  2.68530103]
#
# 5280
#  [9.35760935 9.35685177 9.35382147 ... 1.95602702 1.95223914 1.95905732]
#
# 5360
#  [9.25073135 9.24625374 9.23879105 ... 0.99628357 0.99852238 0.99926865]
#
# 5440
#  [9.15214389 9.15434977 9.15287918 ... 0.57420271 0.59773212 0.61537918]
#
# 5520
#  [9.1346749  9.13177635 9.12380533 ... 1.25134156 1.26583432 1.27670388]
#
# 5600
#  [9.0141336  9.00984788 9.00341931 ... 2.44169054 2.44954768 2.46383339]
#
# 5680
#  [8.91177655 8.90966388 8.90543853 ... 3.00514255 3.04035382 3.07486086]
#
# 5729
#  [8.92545721 8.94073499 8.94976276 ... 4.02209571 4.04709571 4.07001237]
#
# 5709
#  [8.80999593 8.79766716 8.7832836  ... 3.94983116 3.97106404 3.97791335]
#
# 5689
#  [8.63414171 8.62941198 8.6233309  ... 3.84843863 3.8741143  3.88492511]
#
# 5669
#  [8.56631027 8.55897694 8.54897694 ... 3.60374989 3.63108323 3.64974989]
#
# 5649
#  [8.50092176 8.4963165  8.48644808 ... 3.39313192 3.40563192 3.41418455]
#
# 5629
#  [8.3274914  8.32229659 8.31710179 ... 3.38993259 3.40681571 3.41915337]
#
# 5609
#  [8.20722591 8.20273873 8.19632848 ... 3.38296914 3.39386658 3.39578965]
#
# 5589
#  [8.10646082 8.09760006 8.0887393  ... 3.11985287 3.14959971 3.17238452]
#
# 5569
#  [7.95196486 7.94446486 7.93821486 ... 2.87831451 2.89518951 2.90706451]
#
# 5549
#  [7.9210367  7.91548114 7.90375274 ... 2.73224622 2.74706104 2.75878943]
#
# 5529
#  [7.77074093 7.76647263 7.76525312 ... 2.62327717 2.64035034 2.65254546]
#
# 5509
#  [7.74213903 7.7337053  7.72225951 ... 2.50066881 2.51331942 2.52054833]
#
# 5489
#  [7.64636099 7.64517052 7.64219433 ... 2.39883685 2.42205113 2.43931304]
#
# 5469
#  [7.5551895  7.54871891 7.54224832 ... 2.25587152 2.27528328 2.28881269]
#
# 5449
#  [7.44637082 7.44171966 7.43823129 ... 2.13192864 2.15111468 2.16623096]
#
# 5429
#  [7.36534109 7.36246752 7.35844453 ... 1.90968559 1.92750168 1.93784651]
#
# 5409
#  [7.26967566 7.26569839 7.2622893  ... 1.7243117  1.7493117  1.76862989]
#
# 5389
#  [7.19863193 7.18795777 7.17728362 ... 1.48355296 1.50883386 1.52737319]
#
# 3600
#  [6.96027806 6.94805584 6.93916695 ... 3.0832163  3.08488297 3.08932742]
#
# 3640
#  [6.80738252 6.80408582 6.79804186 ... 3.67354597 3.68508444 3.69277674]
#
# 3680
#  [6.67846297 6.67411514 6.6675934  ... 3.93310761 3.94886848 3.95973804]
#
# 3720
#  [6.4980148  6.49263846 6.48511158 ... 4.38547437 4.38547437 4.38547437]
#
# 3760
#  [6.37885277 6.36874639 6.35704426 ... 4.77502481 4.78193971 4.7851312 ]
#
# 3800
#  [6.19535731 6.1916731  6.18272573 ... 4.95111104 4.95058473 4.94900578]
#
# 3840
#  [6.10630966 6.105268   6.102143   ... 5.02300797 5.03082047 5.03863297]
#
# 3880
#  [6.06909806 6.05724239 6.0428094  ... 4.77626277 4.78244834 4.78811844]
#
# 3920
#  [5.89284995 5.88417648 5.8734622  ... 4.51633372 4.5132725  4.51174189]
#
# 3960
#  [5.82167756 5.81763716 5.81410181 ... 4.49246385 4.48943355 4.48387799]
#
# 4000
#  [5.70442863 5.69942863 5.69042863 ... 4.46607137 4.46957137 4.47407137]
#
# 4040
#  [5.55435293 5.54445194 5.535046   ... 4.49168667 4.48871637 4.48871637]
#
# 4080
#  [5.43074931 5.42388657 5.41849441 ... 4.44474088 4.43983892 4.42905461]
#
# 4120
#  [5.32119625 5.31197295 5.30129334 ... 4.15792996 4.15890084 4.16132802]
#
# 4160
#  [5.26759613 5.27192305 5.27096151 ... 4.41605772 4.41509618 4.41269233]
#
# 4200
#  [5.21168363 5.21263601 5.21644553 ... 4.34498304 4.33926875 4.33260209]
#
# 4240
#  [5.23514165 5.23285153 5.22914631 ... 4.07760788 4.06723052 4.05779656]
#
# 4280
#  [5.38638821 5.38732279 5.3868555  ... 3.99794067 4.00588459 4.01709955]
#
# 4320
#  [5.41704002 5.41750298 5.41796595 ... 3.94243396 3.93641544 3.92993396]
#
# 4360
#  [5.44942299 5.45125785 5.45309272 ... 3.57189068 3.56684481 3.55950536]
#
# 4400
#  [5.55348991 5.55258081 5.55121718 ... 3.56672091 3.56172091 3.55899364]
#
# 4440
#  [5.55613219 5.55387994 5.55162769 ... 3.39632898 3.39452718 3.39092357]
#
# 4480
#  [5.54488801 5.54444158 5.54265587 ... 3.0968369  3.09237262 3.08567619]
#
# 4520
#  [5.56924107 5.57012602 5.56924107 ... 2.8880438  2.89025619 2.89423849]
#
# 4560
#  [5.5655353  5.55807916 5.55106162 ... 2.66624707 2.66668566 2.67238742]
#
# 4600
#  [5.48841572 5.48493746 5.48015485 ... 2.45352506 2.44656854 2.43917723]
#
# 4640
#  [5.42512579 5.42469476 5.42297062 ... 1.99163459 1.98861735 1.98516907]
#
# 4680
#  [5.36761859 5.36377244 5.36035364 ... 1.85626349 1.85540879 1.85669084]
#
# 4720
#  [5.28778101 5.28481491 5.28100135 ... 1.81386479 1.8036953  1.79183089]
#
# 4760
#  [5.28239448 5.2794533  5.27441128 ... 1.33478371 1.31839715 1.31539508]
#
# 4769
#  [5.21126439 5.21209772 5.21168105 ... 0.9980291  0.9892791  0.98511243]
#
# 4749
#  [5.23469843 5.23097942 5.22312818 ... 1.04435296 1.03319593 1.02575792]
#
# 4729
#  [5.08643684 5.07864995 5.07045323 ... 1.10917971 1.10098299 1.09483545]
#
# 4709
#  [4.99383803 4.98814697 4.9812364  ... 1.18189545 1.17457838 1.17091984]
#
# 4689
#  [4.89507146 4.88741017 4.87934566 ... 1.08892223 1.08287385 1.07964804]
#
# 4669
#  [4.77668516 4.76948516 4.76228516 ... 1.11103659 1.09703659 1.08503659]
#
# 4649
#  [4.66890816 4.66176531 4.65263832 ... 1.16097452 1.14629198 1.13518087]
#
# 4629
#  [4.56400955 4.55928514 4.55534813 ... 1.16288194 1.15579532 1.15028351]
#
# 4609
#  [4.48887497 4.49160935 4.49278122 ... 1.2077283  1.19640017 1.18858767]
#
# 4589
#  [4.39940139 4.39048667 4.38079674 ... 1.26428247 1.25149177 1.24257704]
#
# 4569
#  [4.27245818 4.2678428  4.26322741 ... 1.35035119 1.34842811 1.34496657]
#
# 4549
#  [4.30623166 4.30012479 4.2924912  ... 1.31983871 1.30953337 1.30304482]
#
# 4529
#  [4.24744796 4.24366008 4.23835705 ... 1.43410672 1.42274309 1.41251581]
#
# 4509
#  [4.22375876 4.21398432 4.20157831 ... 1.39515266 1.38537822 1.37823537]
#
# 4489
#  [4.07430372 4.06572163 4.05676641 ... 1.25901881 1.25939194 1.26498895]
#
# 4469
#  [3.97409987 3.96780357 3.96039616 ... 1.24749434 1.23934619 1.23342027]
#
# 4449
#  [3.89117842 3.88456078 3.87684019 ... 1.26003642 1.25341877 1.25047759]
#
# 4429
#  [3.82771569 3.82479598 3.8185916  ... 1.28188444 1.27385525 1.26874576]
#
# 4409
#  [3.72096981 3.71589734 3.71154952 ... 1.31319844 1.30414047 1.29798105]
#
# 4389
#  [3.68410516 3.67906919 3.67187494 ... 1.32751512 1.323918   1.32319857]
#
# 4369
#  [3.70348143 3.69848143 3.69205286 ... 1.34341298 1.33698441 1.33234156]
#
# 4349
#  [3.67258287 3.66797294 3.66229918 ... 1.34773783 1.34064563 1.33568109]
#
# 4329
#  [3.70549977 3.70796456 3.70972513 ... 1.33404402 1.32700176 1.3252412 ]
#
# 4309
#  [3.75508917 3.75613812 3.75508917 ... 1.37054173 1.35760466 1.34781445]
#
# 4289
#  [3.72725372 3.73280927 3.73662872 ... 1.36937974 1.36625474 1.36347697]
#
# 4269
#  [3.85394013 3.86014703 3.86462979 ... 1.22719931 1.22271655 1.22099241]
#
# 4249
#  [3.94019248 3.94327468 3.94841166 ... 1.19895285 1.19176107 1.18867887]
#
# 4229
#  [4.03989719 4.04023732 4.04261827 ... 1.19558049 1.1891179  1.184356  ]
#
# 4209
#  [4.14703831 4.15311939 4.15784912 ... 1.21015911 1.20509154 1.20407803]
#
# 4189
#  [4.26515741 4.26851311 4.27220439 ... 1.24266285 1.23561587 1.23091788]
#
# 4169
#  [4.38203492 4.38203492 4.37803492 ... 1.13206654 1.12906654 1.12906654]
#
# 4149
#  [4.38908623 4.39537762 4.39835776 ... 0.98717349 0.99081588 0.99843177]
#
# 4129
#  [4.38782108 4.38946582 4.39012372 ... 0.8231343  0.82576588 0.83070009]
#
# 4109
#  [4.42938293 4.43493849 4.44016725 ... 0.80960542 0.80110869 0.79620673]
#
# 4089
#  [4.52008034 4.52267774 4.52332709 ... 0.86183666 0.85242108 0.8469016 ]
#
# 4069
#  [4.54283326 4.53638165 4.5289623  ... 0.90403911 0.89952298 0.89855524]
#
# 4049
#  [4.50696115 4.50984577 4.51080731 ... 0.8431364  0.84025179 0.84153384]
#
# 4029
#  [4.49320206 4.48587722 4.47696002 ... 0.85721334 0.85179933 0.8498885 ]
#
# 4009
#  [4.37993359 4.3777184  4.37676903 ... 0.86288425 0.85687159 0.85307412]
#
# 3989
#  [4.45676912 4.45991378 4.46180057 ... 0.87131401 0.8650247  0.86125112]
#
# 3969
#  [4.54420672 4.54701922 4.55014422 ... 0.8999509  0.8905759  0.8865134 ]
#
# 3949
#  [4.58676931 4.59142769 4.59453328 ... 0.96736249 0.95618236 0.94872895]
#
# 3929
#  [4.54053483 4.53528791 4.52849779 ... 1.01202825 1.00369492 0.99813936]
#
# 3909
#  [4.4629658  4.45989832 4.45775108 ... 1.04111529 1.02945885 1.02179014]
#
# 3889
#  [4.41683054 4.41317201 4.40920859 ... 1.10216469 1.09515249 1.09027445]
#
# 3869
#  [4.38186056 4.37943632 4.37670905 ... 1.10429228 1.09701955 1.09217106]
#
# 3849
#  [4.32381793 4.32050468 4.3153842  ... 1.13049061 1.12085206 1.11543037]
#
# 3829
#  [4.25389557 4.25090156 4.24790755 ... 1.15308178 1.14409975 1.13841113]
#
# 3809
#  [4.20593657 4.2017699  4.197008   ... 1.0908802  1.08968973 1.09266592]
#
# 3789
#  [4.14316052 4.13931437 4.13428478 ... 1.13976977 1.1297106  1.12379344]
#
# 3769
#  [4.07700536 4.07229948 4.06729948 ... 1.14573122 1.14514298 1.14779004]
#
# 3749
#  [4.0048988  4.0046064  4.0046064  ... 1.03729546 1.03583347 1.03671066]
#
# 3729
#  [3.96909581 3.96357255 3.95833999 ... 0.96064383 0.95570197 0.95512058]
#
# 3709
#  [3.88948707 3.88630788 3.88255065 ... 1.00482055 0.99643905 0.99123674]
#
# 3689
#  [3.85734509 3.85389682 3.85389682 ... 0.9122826  0.91142053 0.91256995]
#
# 3669
#  [3.94757046 3.95099903 3.95385617 ... 0.81223079 0.80908793 0.81137365]
#
# 3649
#  [3.99785008 4.00296371 4.00694099 ... 0.85877048 0.85337275 0.84939548]
#
# 3629
#  [4.09732002 4.09449516 4.08912793 ... 0.76947357 0.76890859 0.77003854]
#
# 3609
#  [4.01950802 4.01501364 4.00967656 ... 0.72191032 0.71207886 0.70533729]
#
# 3589
#  [3.96155984 3.95988386 3.95764922 ... 0.77515784 0.76733661 0.76258801]
#
# 3589
#  [3.93955117 3.93788451 3.93566228 ... 0.77085141 0.76307363 0.75835141]
#
# 3589
#  [3.9177857  3.91612824 3.91391829 ... 0.76659256 0.75885775 0.75416162]
#
# 3589
#  [3.8962594  3.89461105 3.89241325 ... 0.76238051 0.75468821 0.75001788]
#
# 3589
#  [3.87496837 3.87332902 3.87114323 ... 0.7582145  0.75056423 0.74591942]
#
# 3589
#  [3.85390876 3.85227832 3.85010441 ... 0.75409377 0.74648507 0.74186551]
#
# 3589
#  [3.83307682 3.8314552  3.82929303 ... 0.75001759 0.74245002 0.73785543]
#
# 3589
#  [3.81246888 3.81085597 3.80870544 ... 0.74598523 0.73845835 0.73388846]
#
# 3589
#  [3.79208134 3.79047706 3.78833803 ... 0.74199601 0.73450938 0.72996392]
#
# 3589
#  [3.7719107  3.77031495 3.76818729 ... 0.73804922 0.73060241 0.72608114]
#
# 3589
#  [3.7519535  3.7503662  3.74824979 ... 0.7341442  0.72673679 0.72223944]
#
# 3589
#  [3.73220637 3.73062743 3.72852216 ... 0.73028028 0.72291186 0.71843818]
#
# 3589
#  [3.71266603 3.71109535 3.70900111 ... 0.72645683 0.71912698 0.71467672]
#
# 3589
#  [3.69332922 3.69176672 3.68968339 ... 0.7226732  0.71538153 0.71095445]
#
# 3589
#  [3.6741928  3.6726384  3.67056586 ... 0.71892878 0.71167489 0.70727074]
#
# 3589
#  [3.65525367 3.65370727 3.65164542 ... 0.71522296 0.70800646 0.70362502]
#
# 3589
#  [3.63650878 3.63497031 3.63291903 ... 0.71155515 0.70437566 0.70001669]
#
# 3589
#  [3.61795516 3.61642455 3.61438373 ... 0.70792476 0.70078191 0.69644517]
#
# 3589
#  [3.5995899  3.59806706 3.5960366  ... 0.70433124 0.69722464 0.69290992]
#
# 3589
#  [3.58141016 3.57989501 3.5778748  ... 0.70077401 0.6937033  0.68941037]
#
# 3589
#  [3.56341312 3.56190558 3.55989553 ... 0.69725253 0.69021736 0.685946  ]

# %%
plt.scatter(index, mean, s=0.5)
plt.yscale('log')
plt.xscale('log')

# %% [markdown]
# # Frequencies filter

# %%
import scipy.fftpack as fft
c = a.copy()
c = c.values
c = c[~np.isnan(c)]

index=range(len(c))
plt.plot(index, c)

# %%
cf = fft.fft(c) 
plt.plot(index, cf)
plt.yscale('log')
# Out:
# /home/vepe/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
cf = cf[cf<0.005]
c = fft.ifft(cf)
plt.plot(index, c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_636/2092847507.py in <module>
#       1 cf = cf[cf<0.005]
#       2 len(cf)
# ----> 3 c = fft.ifft(cf)
#       4 plt.plot(index, c)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/fftpack/basic.py in ifft(x, n, axis, overwrite_x)
#     141
#     142     """
# --> 143     return _pocketfft.ifft(x, n, axis, None, overwrite_x)
#     144
#     145
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/fft/_pocketfft/basic.py in c2c(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      24         overwrite_x = overwrite_x or copied
#      25     elif tmp.shape[axis] < 1:
# ---> 26         raise ValueError("invalid number of data points ({0}) specified"
#      27                          .format(tmp.shape[axis]))
#      28
#
# ValueError: invalid number of data points (0) specified

# %% [markdown]
# # Detreanding and filtering

# %%
c = a.copy()
c = c.values/250
c = c[~np.isnan(c)]
print(c)
detrend.polynomial(c, order=1, plot=False)
index=[]
comulative=[]
for i, c_i in enumerate(c):
    index.append(i)
    comulative.append(c_i)
cf = fft.fft(comulative) 
plt.plot(index, cf)
plt.yscale('log')
# Out:
# [1.01142028e+00 2.00342028e+00 2.98342028e+00 ... 7.25461003e+03
#  7.25554603e+03 7.25652203e+03]
# /home/vepe/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
cf = cf[cf<0.005]
c = fft.ifft(cf)
plt.plot(index, c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_636/673878032.py in <module>
#       1 cf = cf[cf<0.005]
#       2 c = fft.ifft(cf)
# ----> 3 plt.plot(index, c)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (7169,) and (223,)

# %% [markdown]
# # RR invervals

# %%
S=np.arange(200, 4000, 20, dtype=int)
a=pd.DataFrame(RR_intervals.loc[:, 'f1o01'])
print(a, type(a))
# Out:
#           f1o01
# 0     252.85507
# 1     248.00000
# 2     245.00000
# 3     247.00000
# 4     250.00000
# ...         ...
# 9243        NaN
# 9244        NaN
# 9245        NaN
# 9246        NaN
# 9247        NaN
#
# [9248 rows x 1 columns] <class 'pandas.core.frame.DataFrame'>

# %%
c = a.copy()
c = c.values
c = c[~np.isnan(c)]
index=range(len(c))
plt.plot(index, c)

# %%
c_fft = fft.fft(c)
power=abs(c_fft)
sample_c = fft.fftfreq(c.size, d=1/250)

plt.plot(sample_c, power)

pos_mask = np.where(sample_c> 0)
freqs = sample_c[pos_mask]
peak_freq = freqs[power[pos_mask].argmax()]

# %%
high_freq_fft = c_fft.copy()
high_freq_fft[np.abs(sample_c) > peak_freq] = 0
filtered_sig = fft.ifft(high_freq_fft)

# %%
plt.plot(index, c)
plt.plot(index, filtered_sig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_636/3408256554.py in <module>
# ----> 1 plt.plot(index, c)
#       2 plt.plot(index, filtered_sig)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (7169,) and (3711,)
